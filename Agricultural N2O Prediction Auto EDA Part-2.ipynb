# %% [markdown]
# https://www.taskade.com/d/JubswL9vNKx2eTSp?share=check&check=Li6GeQzeZdhrDWXh

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Saha_et_al_2020_ERL_Data.csv')

# %%
df
# Out:
#             Date  Year Experiment   DataUse Replication     Month Vegetation  \
# 0         2/9/12  2012   BCSE_KBS  Building          R1  February       Corn
# 1        2/10/12  2012   BCSE_KBS  Building          R1  February       Corn
# 2        2/18/12  2012   BCSE_KBS  Building          R1  February       Corn
# 3        2/19/12  2012   BCSE_KBS  Building          R1  February       Corn
# 4        3/16/12  2012   BCSE_KBS  Building          R1     March       Corn
# ...          ...   ...        ...       ...         ...       ...        ...
# 2241  10/16/2013  2013    MCSE-T2   Testing          R4   October      TRIAE
# 2242  11/15/2013  2013    MCSE-T2   Testing          R1  November      TRIAE
# 2243  11/15/2013  2013    MCSE-T2   Testing          R2  November      TRIAE
# 2244  11/15/2013  2013    MCSE-T2   Testing          R3  November      TRIAE
# 2245  11/15/2013  2013    MCSE-T2   Testing          R4  November      TRIAE
#
#      VegType       N2O  N_rate  ...   PP7   AirT  DAF_TD  DAF_SD  WFPS25cm  \
# 0     Annual  3.896742     170  ...  0.00  -2.00     276     241  0.666508
# 1     Annual  2.190218     170  ...  0.00  -2.40     277     242  0.640608
# 2     Annual  3.542594     170  ...  8.64   0.30     285     250  0.728085
# 3     Annual  3.342870     170  ...  8.13  -3.80     286     251  0.686872
# 4     Annual  2.947778     170  ...  8.39  17.60     312     277  0.716221
# ...      ...       ...     ...  ...   ...    ...     ...     ...       ...
# 2241  Annual  1.640000      91  ...  8.13  10.81     167     167  0.390203
# 2242  Annual  0.990000      91  ...  8.13   5.64     197     197  0.317040
# 2243  Annual -0.200000      91  ...  8.13   5.64     197     197  0.341428
# 2244  Annual  0.300000      91  ...  8.13   5.64     197     197  0.365815
# 2245  Annual  0.400000      91  ...  8.13   5.64     197     197  0.341428
#
#             NH4        NO3        Clay        Sand       SOM
# 0     11.046340  22.940812   62.500000  637.500000  1.174072
# 1     11.008087  22.959578   62.500000  637.500000  1.174072
# 2     10.831669  23.221928   62.500000  637.500000  1.174072
# 3     10.849792  23.271978   62.500000  637.500000  1.174072
# 4     10.204748  24.206855   62.500000  637.500000  1.174072
# ...         ...        ...         ...         ...       ...
# 2241  17.061793   5.803681  128.333333  491.666667  1.806000
# 2242   5.624730   5.429873  162.500000  490.375000  1.496400
# 2243   3.504328   7.239000  183.250000  432.875000  1.186800
# 2244   3.636931   8.434294  169.833333  418.833333  1.823200
# 2245   7.376583   6.645088  128.333333  491.666667  1.806000
#
# [2246 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2246 entries, 0 to 2245
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         2246 non-null   object
#  1   Year         2246 non-null   int64
#  2   Experiment   2246 non-null   object
#  3   DataUse      2246 non-null   object
#  4   Replication  2246 non-null   object
#  5   Month        2246 non-null   object
#  6   Vegetation   2246 non-null   object
#  7   VegType      2246 non-null   object
#  8   N2O          2246 non-null   float64
#  9   N_rate       2246 non-null   int64
#  10  PP2          2246 non-null   float64
#  11  PP7          2246 non-null   float64
#  12  AirT         2246 non-null   float64
#  13  DAF_TD       2246 non-null   int64
#  14  DAF_SD       2246 non-null   int64
#  15  WFPS25cm     2194 non-null   float64
#  16  NH4          2170 non-null   float64
#  17  NO3          2216 non-null   float64
#  18  Clay         2246 non-null   float64
#  19  Sand         2246 non-null   float64
#  20  SOM          2246 non-null   float64
# dtypes: float64(10), int64(4), object(7)
# memory usage: 368.6+ KB

# %%
df.isnull().sum()
# Out:
# Date            0
# Year            0
# Experiment      0
# DataUse         0
# Replication     0
# Month           0
# Vegetation      0
# VegType         0
# N2O             0
# N_rate          0
# PP2             0
# PP7             0
# AirT            0
# DAF_TD          0
# DAF_SD          0
# WFPS25cm       52
# NH4            76
# NO3            30
# Clay            0
# Sand            0
# SOM             0
# dtype: int64

# %%
df.sample(5)
# Out:
#            Date  Year Experiment   DataUse Replication    Month Vegetation  \
# 153    10/24/12  2012   BCSE_KBS  Building          R1  October       Corn
# 1641  5/18/2005  2005    MCSE-T2   Testing          R2      May       Corn
# 613     7/21/14  2014   BCSE_KBS  Building          R1     July       Corn
# 570      6/3/14  2014   BCSE_KBS  Building          R1     June       Corn
# 630     8/16/14  2014   BCSE_KBS  Building          R1   August       Corn
#
#      VegType       N2O  N_rate  ...     PP7   AirT  DAF_TD  DAF_SD  WFPS25cm  \
# 153   Annual  3.561152     170  ...  54.860  19.20     169     135  0.710324
# 1641  Annual  1.150000     157  ...  19.558  15.86       6     397  0.317040
# 613   Annual  0.252167     170  ...   2.540  22.10      72      33  0.563646
# 570   Annual  4.871280     170  ...   7.370  20.80      24     356  0.674875
# 630   Annual -0.796015     170  ...   2.290  19.00      98      59  0.346385
#
#             NH4        NO3    Clay     Sand       SOM
# 153    9.246452  22.205967   62.50  637.500  1.174072
# 1641        NaN        NaN  183.25  432.875  1.186800
# 613    5.699028  19.096627   62.50  637.500  1.174072
# 570   13.159109  32.321472   62.50  637.500  1.174072
# 630    2.399061  14.470028   62.50  637.500  1.174072
#
# [5 rows x 21 columns]

# %%
import pandas_visual_analysis as pva

# %%
from pandas_visual_analysis import VisualAnalysis

# %%
VisualAnalysis(df)
# Out:
# VBox(children=(ToggleButtons(_dom_classes=('layout-46a9cd1c51b541798c560d05075f3dc4',), description='Selection…

# %%
import klib

# %%
klib.corr_mat(df)
# Out:
# <style type="text/css">
# #T_bbbb5_row0_col0, #T_bbbb5_row0_col1, #T_bbbb5_row0_col2, #T_bbbb5_row0_col3, #T_bbbb5_row0_col4, #T_bbbb5_row0_col8, #T_bbbb5_row0_col9, #T_bbbb5_row0_col10, #T_bbbb5_row0_col12, #T_bbbb5_row1_col0, #T_bbbb5_row1_col1, #T_bbbb5_row1_col2, #T_bbbb5_row1_col3, #T_bbbb5_row1_col4, #T_bbbb5_row1_col5, #T_bbbb5_row1_col8, #T_bbbb5_row1_col9, #T_bbbb5_row1_col10, #T_bbbb5_row1_col11, #T_bbbb5_row1_col13, #T_bbbb5_row2_col0, #T_bbbb5_row2_col1, #T_bbbb5_row2_col2, #T_bbbb5_row2_col3, #T_bbbb5_row2_col4, #T_bbbb5_row2_col8, #T_bbbb5_row2_col9, #T_bbbb5_row2_col10, #T_bbbb5_row2_col12, #T_bbbb5_row2_col13, #T_bbbb5_row3_col0, #T_bbbb5_row3_col1, #T_bbbb5_row3_col2, #T_bbbb5_row3_col3, #T_bbbb5_row3_col4, #T_bbbb5_row3_col5, #T_bbbb5_row3_col8, #T_bbbb5_row3_col9, #T_bbbb5_row3_col10, #T_bbbb5_row3_col11, #T_bbbb5_row3_col13, #T_bbbb5_row4_col0, #T_bbbb5_row4_col1, #T_bbbb5_row4_col2, #T_bbbb5_row4_col3, #T_bbbb5_row4_col4, #T_bbbb5_row4_col5, #T_bbbb5_row4_col8, #T_bbbb5_row4_col9, #T_bbbb5_row4_col11, #T_bbbb5_row4_col13, #T_bbbb5_row5_col1, #T_bbbb5_row5_col3, #T_bbbb5_row5_col4, #T_bbbb5_row5_col5, #T_bbbb5_row5_col9, #T_bbbb5_row5_col10, #T_bbbb5_row5_col11, #T_bbbb5_row5_col13, #T_bbbb5_row6_col6, #T_bbbb5_row6_col7, #T_bbbb5_row6_col11, #T_bbbb5_row6_col12, #T_bbbb5_row7_col6, #T_bbbb5_row7_col7, #T_bbbb5_row7_col8, #T_bbbb5_row7_col11, #T_bbbb5_row8_col0, #T_bbbb5_row8_col1, #T_bbbb5_row8_col2, #T_bbbb5_row8_col3, #T_bbbb5_row8_col4, #T_bbbb5_row8_col7, #T_bbbb5_row8_col8, #T_bbbb5_row8_col9, #T_bbbb5_row8_col10, #T_bbbb5_row8_col12, #T_bbbb5_row9_col0, #T_bbbb5_row9_col1, #T_bbbb5_row9_col2, #T_bbbb5_row9_col3, #T_bbbb5_row9_col4, #T_bbbb5_row9_col5, #T_bbbb5_row9_col8, #T_bbbb5_row9_col9, #T_bbbb5_row9_col10, #T_bbbb5_row9_col11, #T_bbbb5_row9_col13, #T_bbbb5_row10_col0, #T_bbbb5_row10_col1, #T_bbbb5_row10_col2, #T_bbbb5_row10_col3, #T_bbbb5_row10_col5, #T_bbbb5_row10_col8, #T_bbbb5_row10_col9, #T_bbbb5_row10_col10, #T_bbbb5_row10_col11, #T_bbbb5_row10_col13, #T_bbbb5_row11_col1, #T_bbbb5_row11_col3, #T_bbbb5_row11_col4, #T_bbbb5_row11_col5, #T_bbbb5_row11_col6, #T_bbbb5_row11_col7, #T_bbbb5_row11_col9, #T_bbbb5_row11_col10, #T_bbbb5_row11_col11, #T_bbbb5_row11_col13, #T_bbbb5_row12_col0, #T_bbbb5_row12_col2, #T_bbbb5_row12_col6, #T_bbbb5_row12_col8, #T_bbbb5_row12_col12, #T_bbbb5_row13_col1, #T_bbbb5_row13_col2, #T_bbbb5_row13_col3, #T_bbbb5_row13_col4, #T_bbbb5_row13_col5, #T_bbbb5_row13_col9, #T_bbbb5_row13_col10, #T_bbbb5_row13_col11, #T_bbbb5_row13_col13 {
#   color: None;
# }
# #T_bbbb5_row0_col5, #T_bbbb5_row0_col6, #T_bbbb5_row0_col7, #T_bbbb5_row0_col11, #T_bbbb5_row0_col13, #T_bbbb5_row1_col6, #T_bbbb5_row1_col7, #T_bbbb5_row1_col12, #T_bbbb5_row2_col5, #T_bbbb5_row2_col6, #T_bbbb5_row2_col7, #T_bbbb5_row2_col11, #T_bbbb5_row3_col6, #T_bbbb5_row3_col7, #T_bbbb5_row3_col12, #T_bbbb5_row4_col6, #T_bbbb5_row4_col7, #T_bbbb5_row4_col10, #T_bbbb5_row4_col12, #T_bbbb5_row5_col0, #T_bbbb5_row5_col2, #T_bbbb5_row5_col6, #T_bbbb5_row5_col7, #T_bbbb5_row5_col8, #T_bbbb5_row5_col12, #T_bbbb5_row6_col0, #T_bbbb5_row6_col1, #T_bbbb5_row6_col2, #T_bbbb5_row6_col3, #T_bbbb5_row6_col4, #T_bbbb5_row6_col5, #T_bbbb5_row6_col8, #T_bbbb5_row6_col9, #T_bbbb5_row6_col10, #T_bbbb5_row6_col13, #T_bbbb5_row7_col0, #T_bbbb5_row7_col1, #T_bbbb5_row7_col2, #T_bbbb5_row7_col3, #T_bbbb5_row7_col4, #T_bbbb5_row7_col5, #T_bbbb5_row7_col9, #T_bbbb5_row7_col10, #T_bbbb5_row7_col12, #T_bbbb5_row7_col13, #T_bbbb5_row8_col5, #T_bbbb5_row8_col6, #T_bbbb5_row8_col11, #T_bbbb5_row8_col13, #T_bbbb5_row9_col6, #T_bbbb5_row9_col7, #T_bbbb5_row9_col12, #T_bbbb5_row10_col4, #T_bbbb5_row10_col6, #T_bbbb5_row10_col7, #T_bbbb5_row10_col12, #T_bbbb5_row11_col0, #T_bbbb5_row11_col2, #T_bbbb5_row11_col8, #T_bbbb5_row11_col12, #T_bbbb5_row12_col1, #T_bbbb5_row12_col3, #T_bbbb5_row12_col4, #T_bbbb5_row12_col5, #T_bbbb5_row12_col7, #T_bbbb5_row12_col9, #T_bbbb5_row12_col10, #T_bbbb5_row12_col11, #T_bbbb5_row12_col13, #T_bbbb5_row13_col0, #T_bbbb5_row13_col6, #T_bbbb5_row13_col7, #T_bbbb5_row13_col8, #T_bbbb5_row13_col12 {
#   color: #FF3344;
# }
# </style>
# <table id="T_bbbb5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Year</th>
#       <th class="col_heading level0 col1" >N2O</th>
#       <th class="col_heading level0 col2" >N_rate</th>
#       <th class="col_heading level0 col3" >PP2</th>
#       <th class="col_heading level0 col4" >PP7</th>
#       <th class="col_heading level0 col5" >AirT</th>
#       <th class="col_heading level0 col6" >DAF_TD</th>
#       <th class="col_heading level0 col7" >DAF_SD</th>
#       <th class="col_heading level0 col8" >WFPS25cm</th>
#       <th class="col_heading level0 col9" >NH4</th>
#       <th class="col_heading level0 col10" >NO3</th>
#       <th class="col_heading level0 col11" >Clay</th>
#       <th class="col_heading level0 col12" >Sand</th>
#       <th class="col_heading level0 col13" >SOM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbbb5_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_bbbb5_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_bbbb5_row0_col1" class="data row0 col1" >0.01</td>
#       <td id="T_bbbb5_row0_col2" class="data row0 col2" >0.51</td>
#       <td id="T_bbbb5_row0_col3" class="data row0 col3" >0.05</td>
#       <td id="T_bbbb5_row0_col4" class="data row0 col4" >0.03</td>
#       <td id="T_bbbb5_row0_col5" class="data row0 col5" >-0.17</td>
#       <td id="T_bbbb5_row0_col6" class="data row0 col6" >-0.22</td>
#       <td id="T_bbbb5_row0_col7" class="data row0 col7" >-0.16</td>
#       <td id="T_bbbb5_row0_col8" class="data row0 col8" >0.58</td>
#       <td id="T_bbbb5_row0_col9" class="data row0 col9" >0.07</td>
#       <td id="T_bbbb5_row0_col10" class="data row0 col10" >0.09</td>
#       <td id="T_bbbb5_row0_col11" class="data row0 col11" >-0.37</td>
#       <td id="T_bbbb5_row0_col12" class="data row0 col12" >0.24</td>
#       <td id="T_bbbb5_row0_col13" class="data row0 col13" >-0.09</td>
#     </tr>
#     <tr>
#       <th id="T_bbbb5_level0_row1" class="row_heading level0 row1" >N2O</th>
#       <td id="T_bbbb5_row1_col0" class="data row1 col0" >0.01</td>
#       <td id="T_bbbb5_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_bbbb5_row1_col2" class="data row1 col2" >0.06</td>
#       <td id="T_bbbb5_row1_col3" class="data row1 col3" >0.15</td>
#       <td id="T_bbbb5_row1_col4" class="data row1 col4" >0.21</td>
#       <td id="T_bbbb5_row1_col5" class="data row1 col5" >0.12</td>
#       <td id="T_bbbb5_row1_col6" class="data row1 col6" >-0.14</td>
#       <td id="T_bbbb5_row1_col7" class="data row1 col7" >-0.16</td>
#       <td id="T_bbbb5_row1_col8" class="data row1 col8" >0.15</td>
#       <td id="T_bbbb5_row1_col9" class="data row1 col9" >0.50</td>
#       <td id="T_bbbb5_row1_col10" class="data row1 col10" >0.36</td>
#       <td id="T_bbbb5_row1_col11" class="data row1 col11" >0.15</td>
#       <td id="T_bbbb5_row1_col12" class="data row1 col12" >-0.17</td>
#       <td id="T_bbbb5_row1_col13" class="data row1 col13" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_bbbb5_level0_row2" class="row_heading level0 row2" >N_rate</th>
#       <td id="T_bbbb5_row2_col0" class="data row2 col0" >0.51</td>
#       <td id="T_bbbb5_row2_col1" class="data row2 col1" >0.06</td>
#       <td id="T_bbbb5_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_bbbb5_row2_col3" class="data row2 col3" >0.05</td>
#       <td id="T_bbbb5_row2_col4" class="data row2 col4" >0.04</td>
#       <td id="T_bbbb5_row2_col5" class="data row2 col5" >-0.12</td>
#       <td id="T_bbbb5_row2_col6" class="data row2 col6" >-0.45</td>
#       <td id="T_bbbb5_row2_col7" class="data row2 col7" >-0.35</td>
#       <td id="T_bbbb5_row2_col8" class="data row2 col8" >0.47</td>
#       <td id="T_bbbb5_row2_col9" class="data row2 col9" >0.14</td>
#       <td id="T_bbbb5_row2_col10" class="data row2 col10" >0.25</td>
#       <td id="T_bbbb5_row2_col11" class="data row2 col11" >-0.24</td>
#       <td id="T_bbbb5_row2_col12" cl

# %%
klib.dist_plot(df)
# Out:
# <AxesSubplot:xlabel='SOM', ylabel='Density'>

# %%
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)

# %%
klib.feature_selection_pipe()
# Out:
# Pipeline(steps=[('variancethreshold', VarianceThreshold(threshold=0.1)),
#                 ('pipeinfo-1', PipeInfo(name='after var_thresh')),
#                 ('selectfrommodel',
#                  SelectFromModel(estimator=LassoCV(cv=4, random_state=408),
#                                  threshold='0.1*median')),
#                 ('pipeinfo-2', PipeInfo(name='after select_from_model')),
#                 ('selectpercentile', SelectPercentile(percentile=95)),
#                 ('pipeinfo-3', PipeInfo(name='after select_percentile'))])

# %%
import sweetviz as sv

# %%
my_report = sv.analyze(df)
my_report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
